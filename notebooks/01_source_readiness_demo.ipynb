# %% [markdown]
# # 01 — Source readiness demo
#
# This notebook demonstrates how the public repository records source provenance and version lineage.

# %%
import pandas as pd, json
sources = pd.read_csv('../data/sources/source_registry_public.csv')
versions = pd.read_csv('../data/summaries/version_metrics.csv')
metrics = json.load(open('../data/summaries/project_metrics.json'))
print('Public source rows:', len(sources))
print('Project title:', metrics['project_title'])
sources.head()

# %%
versions
